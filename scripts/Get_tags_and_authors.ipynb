# %%
import pandas as pd
import numpy as np
from unidecode import unidecode

# %%
df_main = pd.read_csv(r'../data/AWARDS_ngrams_1000.csv')
df_main.set_index("Unnamed: 0", inplace = True)
df_main = df_main.replace(np.nan, 0)

# %%
df_main[:1]
# Out:
#                                            le        il        de       un  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes  0.0991  0.074558  0.050445  0.03743
#
#                                            être     avoir         à        se  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes  0.025752  0.022499  0.020002  0.019825
#
#                                             son       que  ...  le_blanc  \
# Unnamed: 0                                                 ...
# 1954_San-Antonio_Messieurs-les-hommes  0.019169  0.018463  ...  0.000101
#
#                                        un_bruit  le_hauteur  hauteur_de  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes  0.000101    0.000101    0.000101
#
#                                         un_taxi  montrer_le  gardien_de  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes  0.000101    0.000101    0.000101
#
#                                        avec_paul  son_épaule        AWARD
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes   0.000101     0.000101  not_awarded
#
# [1 rows x 2001 columns]

# %% [markdown]
# ### GET PRIX

# %%
df_prix = pd.read_csv(r'../metadata/csv_prix.csv', encoding='latin')

# %%
liste_net = [unidecode(elem).lower().replace('-',' ').replace("'",' ') for elem in df_prix.Roman]

# %%
def get_roman(list_roman):
    list_titre = []
    for elem in list_roman:
        titre = elem.split('_')[2]
        list_titre.append(' '.join(titre.lower().split('-')))
    return list_titre

# %%
list_romans_chapitre = get_roman(list(df_main.index))

# %%
def get_award(list_corpus, list_prix):
    list_award = []
    for elem in list_corpus:
        if elem in list_prix:
            list_award.append('awarded')
        else:
            list_award.append('not_awarded')
    return list_award

# %%
list_award = get_award(list_romans_chapitre, liste_net)

# %%
df_main["AWARD"] = list_award

# %% [markdown]
# ### GET AUTHORS

# %%
def get_df_with_authors_dates(df):
    df_res = df.copy()
    list_author, list_date = [], []
    for elem in df_res.index:
        list_author.append(elem.split('_')[1])
        list_date.append(int(elem.split('_')[0]))
    print(len(set(list_author)))
    df_res['auteur'] = list_author
    df_res['date'] = list_date
    return df_res

# %%
df_award_authors = get_df_with_authors_dates(df_main)
# Out:
# 714

# %%
df_final = df_award_authors[df_award_authors['date']>=1900]

# %%
del df_final['date']

# %%
df_final
# Out:
#                                                           le        il  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               0.099100  0.074558
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.098007  0.061353
# 1957_Simenon-Georges_Maigret-voyage                 0.108749  0.060910
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.102136  0.050430
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.103606  0.044720
# ...                                                      ...       ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.108946  0.023541
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.083677  0.065922
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.092847  0.053714
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.104784  0.053321
# 1926_Crevel-René_La-mort-difficile                  0.084949  0.050965
#
#                                                           de        un  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               0.050445  0.037430
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.056830  0.039773
# 1957_Simenon-Georges_Maigret-voyage                 0.056294  0.036663
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.063467  0.039902
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.076595  0.040605
# ...                                                      ...       ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.086746  0.040827
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.055767  0.036782
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.063377  0.032763
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.059529  0.033532
# 1926_Crevel-René_La-mort-difficile                  0.060970  0.033796
#
#                                                         être     avoir  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               0.025752  0.022499
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.021704  0.016520
# 1957_Simenon-Georges_Maigret-voyage                 0.025414  0.027940
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.020926  0.021357
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.017753  0.017209
# ...                                                      ...       ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.015931  0.011798
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.025080  0.019327
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.017704  0.017719
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.017318  0.014020
# 1926_Crevel-René_La-mort-difficile                  0.019906  0.023206
#
#                                                            à        se  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               0.020002  0.019825
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.020134  0.008962
# 1957_Simenon-Georges_Maigret-voyage                 0.021842  0.014966
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.017613  0.019750
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.018928  0.017091
# ...                                                      ...       ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.021269  0.012154
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.015070  0.016780
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.016869  0.016513
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.018829  0.014898
# 1926_Crevel-René_La-mort-difficile                  0.020887  0.012491
#
#                                                          son       que  ...  \
# Unnamed: 0                                                              ...
# 1954_San-Antonio_Messieurs-les-hommes               0.019169  0.018463  ...
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.028456  0.012845  ...
# 1957_Simenon-Georges_Maigret-voyage                 0.015185  0.021696  ...
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.020826  0.025674  ...
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.019119  0.018399  ...
# ...                                                      ...       ...  ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.017669  0.010895  ...
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.022319  0.020977  ...
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.021074  0.020487  ...
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.026773  0.019217  ...
# 1926_Crevel-René_La-mort-difficile                  0.026130  0.015603  ...
#
#                                                     un_bruit  le_hauteur  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               0.000101    0.000101
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            0.000124    0.000000
# 1957_Simenon-Georges_Maigret-voyage                 0.000000    0.000000
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  0.000000    0.000143
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  0.000088    0.000000
# ...                                                      ...         ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        0.000000    0.000000
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  0.000000    0.000000
# 1954_Delly_Aelys-aux-cheveux-d'or                   0.000000    0.000000
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       0.000000    0.000000
# 1926_Crevel-René_La-mort-difficile                  0.000000    0.000000
#
#                                                     hauteur_de   un_taxi  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes                 0.000101  0.000101
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere              0.000000  0.000000
# 1957_Simenon-Georges_Maigret-voyage                   0.000000  0.000243
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...    0.000129  0.000000
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...    0.000000  0.000000
# ...                                                        ...       ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin          0.000082  0.000000
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...    0.000000  0.000000
# 1954_Delly_Aelys-aux-cheveux-d'or                     0.000000  0.000000
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan         0.000000  0.000000
# 1926_Crevel-René_La-mort-difficile                    0.000000  0.000000
#
#                                                     montrer_le  gardien_de  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes                 0.000101    0.000101
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere              0.000124    0.000000
# 1957_Simenon-Georges_Maigret-voyage                   0.000000    0.000000
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...    0.000000    0.000000
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...    0.000073    0.000000
# ...                                                        ...         ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin          0.000000    0.000000
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...    0.000000    0.000000
# 1954_Delly_Aelys-aux-cheveux-d'or                     0.000000    0.000000
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan         0.000000    0.000000
# 1926_Crevel-René_La-mort-difficile                    0.000000    0.000000
#
#                                                     avec_paul  son_épaule  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes                0.000101     0.000101
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere             0.000000     0.000248
# 1957_Simenon-Georges_Maigret-voyage                  0.000000     0.000000
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...   0.000000     0.000000
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...   0.000000     0.000073
# ...                                                       ...          ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin         0.000000     0.000000
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...   0.000000     0.000000
# 1954_Delly_Aelys-aux-cheveux-d'or                    0.000000     0.000093
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan        0.000000     0.000102
# 1926_Crevel-René_La-mort-difficile                   0.000000     0.000000
#
#                                                           AWARD  \
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes               not_awarded
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere            not_awarded
# 1957_Simenon-Georges_Maigret-voyage                 not_awarded
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  not_awarded
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  not_awarded
# ...                                                         ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin        not_awarded
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...  not_awarded
# 1954_Delly_Aelys-aux-cheveux-d'or                   not_awarded
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       not_awarded
# 1926_Crevel-René_La-mort-difficile                  not_awarded
#
#                                                               auteur
# Unnamed: 0
# 1954_San-Antonio_Messieurs-les-hommes                    San-Antonio
# 1957_Pagnol-Marcel_La-Gloire-de-mon-pere               Pagnol-Marcel
# 1957_Simenon-Georges_Maigret-voyage                  Simenon-Georges
# 2001_Millet-Catherine_La-Vie-Sexuelle-De-Cather...  Millet-Catherine
# 1908_Le-Rouge-Gustave_Le-Prisonnier-de-la-plane...  Le-Rouge-Gustave
# ...                                                              ...
# 1902_Loti-Pierre_Les-derniers-jours-de-Pekin             Loti-Pierre
# 1900_Mirbeau-Octave_Le-journal-d-une-femme-de-c...    Mirbeau-Octave
# 1954_Delly_Aelys-aux-cheveux-d'or                              Delly
# 1926_Bernanos-Georges_Sous-le-soleil-de-Satan       Bernanos-Georges
# 1926_Crevel-René_La-mort-difficile                       Crevel-René
#
# [1435 rows x 2002 columns]

# %%
df_final.to_csv('../data/df_awards_authors.csv', index=True, header=True)

# %%
import pandas as pd

# %%
df_main = pd.read_csv(r'../data/AWARDS_trigrams_ALL.csv')

# %%
df_main

# %%
def post_process(df, len_max):
    len_ngrams = 1
    conteur_temp = 0
    good_cols = []
    for col in list(df.columns):
        if len(col.split('_')) == len_ngrams and conteur_temp < len_max:
            conteur_temp+=1
            good_cols.append(col)
        elif conteur_temp >= len_max:
            len_ngrams+=1
            conteur_temp=0

    return pd.DataFrame(df, columns=good_cols)

# %%
df_final = post_process(df_main, 1000)

# %%
df_res.to_csv("AWARDS_ngrams_ALL.csv")
